# %%
library(readxl)
library(dplyr)
library(scales)
# Out:
# Warning message:
# "package 'readxl' was built under R version 3.6.3"Warning message:
# "package 'dplyr' was built under R version 3.6.3"
# Attaching package: 'dplyr'
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union
#
# Warning message:
# "package 'scales' was built under R version 3.6.3"

# %%
options(warn=-1)
Diamante <- read_excel("C:/Users/Sabrina/Downloads/Exploracion_d_multivariados/bd_primaria.xlsx", sheet = 1)

# %%
prim_Mat_1 <- filter(Diamante, Curso== 1 & Materia=="MATEMATICA")

# %%
prim_Mat_1[!is.na(prim_Mat_1$Promedio),] %>% 
  mutate(Promedio = cut(Promedio, breaks = 5), na.rm=TRUE) %>% 
  group_by(Promedio) %>% 
  summarise(frequency = n()) %>% 
  mutate(acumulado = cumsum(frequency))

boxplot(prim_Mat_1[!is.na(prim_Mat_1$Promedio),]$Promedio,
        main ="Boxplot para la asignatura Matemática de 1°grado de Primaria",
        horizontal = FALSE,
        sub = "Fuente de elaboración propia",
        whisklty = 2,       # Tipo línea bigotes
        whisklwd = 2,       # Ancho línea bigotes
        whiskcol = "red",   # Color bigotes
        staplelty = 3,      # Tipo línea barras
        staplelwd = 2,      # Ancho línea barras
        staplecol = "blue",  #Color barras
        col ="orange") #color caja

# Añadir línea con la media
abline(h = mean(prim_Mat_1[!is.na(prim_Mat_1$Promedio),]$Promedio), col = 4, lwd = 2) # Línea completa

# Añadir punto con la media
points(mean(prim_Mat_1[!is.na(prim_Mat_1$Promedio),]$Promedio), col = 3, pch = 19)
# Out:
#   Promedio  frequency acumulado
# 1 (6,6.8]   150        150
# 2 (6.8,7.6] 161        311
# 3 (7.6,8.4] 349        660
# 4 (8.4,9.2] 230        890
# 5 (9.2,10]  121       1011
# Plot with title "Boxplot para la asignatura Matemática de 1°grado de Primaria"

# %%
hist(x = prim_Mat_1$Promedio,
     probability = TRUE, 
     col="orange",
     breaks = c(6,6.8,7.6,8.4,9.2,10), #cantidad de barras que quiero
     xaxp = c(6, 10, 5), #acomoda el eje x para ver bien los valores
     ylim = c(0, 0.5),
     xlab="notas",
     ylab="frecuencia absoluta",
     main ="Histograma para la asignatura Matemática de 1°grado de Primaria")
# Out:
# Plot with title "Histograma para la asignatura Matemática de 1°grado de Primaria"

# %%
prim_Mat_2 <- filter(Diamante, Curso== 2 & Materia=="MATEMATICA")

prim_Mat_2[!is.na(prim_Mat_2$Promedio),] %>% 
  mutate(Promedio = cut(Promedio, breaks = 5), na.rm=TRUE) %>% 
  group_by(Promedio) %>% 
  summarise(frequency = n()) %>% 
  mutate(acumulado = cumsum(frequency))

boxplot(prim_Mat_2[!is.na(prim_Mat_2$Promedio),]$Promedio,
        main ="Boxplot para la asignatura Matemática de 2°grado de Primaria",
        horizontal = FALSE,
        sub = "Fuente de elaboración propia",
        whisklty = 2,       # Tipo línea bigotes
        whisklwd = 2,       # Ancho línea bigotes
        whiskcol = "red",   # Color bigotes
        staplelty = 3,      # Tipo línea barras
        staplelwd = 2,      # Ancho línea barras
        staplecol = "blue",  #Color barras
        col ="orange") #color caja

# Añadir línea con la media
abline(h = mean(prim_Mat_2[!is.na(prim_Mat_2$Promedio),]$Promedio), col = 4, lwd = 2) # Línea completa

# Añadir punto con la media
points(mean(prim_Mat_2[!is.na(prim_Mat_2$Promedio),]$Promedio), col = 3, pch = 19)
# Out:
#   Promedio  frequency acumulado
# 1 (6,6.8]    99        99
# 2 (6.8,7.6] 113       212
# 3 (7.6,8.4] 219       431
# 4 (8.4,9.2] 157       588
# 5 (9.2,10]  159       747
# Plot with title "Boxplot para la asignatura Matemática de 2°grado de Primaria"

# %%
hist(x = prim_Mat_2$Promedio,
     probability = TRUE, 
     col="orange",
     breaks = c(6,6.8,7.6,8.4,9.2,10), #cantidad de barras que quiero
     xaxp = c(6, 10, 5), #acomoda el eje x para ver bien los valores
     ylim = c(0, 0.5),
     xlab="notas",
     ylab="frecuencia absoluta",
     main ="Histograma para la asignatura Matemática de 2°grado de Primaria")
# Out:
# Plot with title "Histograma para la asignatura Matemática de 2°grado de Primaria"

# %%
prim_Mat_3 <- filter(Diamante, Curso== 3 & Materia=="MATEMATICA")

prim_Mat_3[!is.na(prim_Mat_3$Promedio),] %>% 
  mutate(Promedio = cut(Promedio, breaks = 5), na.rm=TRUE) %>% 
  group_by(Promedio) %>% 
  summarise(frequency = n()) %>% 
  mutate(acumulado = cumsum(frequency))

boxplot(prim_Mat_3[!is.na(prim_Mat_3$Promedio),]$Promedio,
        main ="Boxplot para la asignatura Matemática de 3°grado de Primaria",
        horizontal = FALSE,
        sub = "Fuente de elaboración propia",
        whisklty = 2,       # Tipo línea bigotes
        whisklwd = 2,       # Ancho línea bigotes
        whiskcol = "red",   # Color bigotes
        staplelty = 3,      # Tipo línea barras
        staplelwd = 2,      # Ancho línea barras
        staplecol = "blue",  #Color barras
        col ="orange") #color caja

# Añadir línea con la media
abline(h = mean(prim_Mat_3[!is.na(prim_Mat_3$Promedio),]$Promedio), col = 4, lwd = 2) # Línea completa

# Añadir punto con la media
points(mean(prim_Mat_3[!is.na(prim_Mat_3$Promedio),]$Promedio), col = 3, pch = 19)
# Out:
#   Promedio  frequency acumulado
# 1 (6,6.8]   112       112
# 2 (6.8,7.6] 134       246
# 3 (7.6,8.4] 238       484
# 4 (8.4,9.2] 139       623
# 5 (9.2,10]   86       709
# Plot with title "Boxplot para la asignatura Matemática de 3°grado de Primaria"

# %%
hist(x = prim_Mat_3$Promedio,
     probability = TRUE, 
     col="orange",
     breaks = c(6,6.8,7.6,8.4,9.2,10), #cantidad de barras que quiero
     xaxp = c(6, 10, 5), #acomoda el eje x para ver bien los valores
     ylim = c(0, 0.5),
     xlab="notas",
     ylab="frecuencia absoluta",
     main ="Histograma para la asignatura Matemática de 3°grado de Primaria")
# Out:
# Plot with title "Histograma para la asignatura Matemática de 3°grado de Primaria"

# %%
prim_Mat_4 <- filter(Diamante, Curso== 4 & Materia=="MATEMATICA")

prim_Mat_4[!is.na(prim_Mat_4$Promedio),] %>% 
  mutate(Promedio = cut(Promedio, breaks = 5), na.rm=TRUE) %>% 
  group_by(Promedio) %>% 
  summarise(frequency = n()) %>% 
  mutate(acumulado = cumsum(frequency))

boxplot(prim_Mat_4[!is.na(prim_Mat_4$Promedio),]$Promedio,
        main ="Boxplot para la asignatura Matemática de 4°grado de Primaria",
        horizontal = FALSE,
        sub = "Fuente de elaboración propia",
        whisklty = 2,       # Tipo línea bigotes
        whisklwd = 2,       # Ancho línea bigotes
        whiskcol = "red",   # Color bigotes
        staplelty = 3,      # Tipo línea barras
        staplelwd = 2,      # Ancho línea barras
        staplecol = "blue",  #Color barras
        col ="orange") #color caja

# Añadir línea con la media
abline(h = mean(prim_Mat_4[!is.na(prim_Mat_4$Promedio),]$Promedio), col = 4, lwd = 2) # Línea completa

# Añadir punto con la media
points(mean(prim_Mat_4[!is.na(prim_Mat_4$Promedio),]$Promedio), col = 3, pch = 19)
# Out:
#   Promedio  frequency acumulado
# 1 (6,6.8]   119       119
# 2 (6.8,7.6] 153       272
# 3 (7.6,8.4] 198       470
# 4 (8.4,9.2] 149       619
# 5 (9.2,10]  106       725
# Plot with title "Boxplot para la asignatura Matemática de 4°grado de Primaria"

# %%
hist(x = prim_Mat_4$Promedio,
     probability = TRUE, 
     col="orange",
     breaks = c(6,6.8,7.6,8.4,9.2,10), #cantidad de barras que quiero
     xaxp = c(6, 10, 5), #acomoda el eje x para ver bien los valores
     ylim = c(0, 0.5),
     xlab="notas",
     ylab="frecuencia absoluta",
     main ="Histograma para la asignatura Matemática de 4°grado de Primaria")
# Out:
# Plot with title "Histograma para la asignatura Matemática de 4°grado de Primaria"

# %%
prim_Mat_5 <- filter(Diamante, Curso== 5 & Materia=="MATEMATICA")

prim_Mat_5[!is.na(prim_Mat_5$Promedio),] %>% 
  mutate(Promedio = cut(Promedio, breaks = 5), na.rm=TRUE) %>% 
  group_by(Promedio) %>% 
  summarise(frequency = n()) %>% 
  mutate(acumulado = cumsum(frequency))

boxplot(prim_Mat_5[!is.na(prim_Mat_5$Promedio),]$Promedio,
        main ="Boxplot para la asignatura Matemática de 5°grado de Primaria",
        horizontal = FALSE,
        sub = "Fuente de elaboración propia",
        whisklty = 2,       # Tipo línea bigotes
        whisklwd = 2,       # Ancho línea bigotes
        whiskcol = "red",   # Color bigotes
        staplelty = 3,      # Tipo línea barras
        staplelwd = 2,      # Ancho línea barras
        staplecol = "blue",  #Color barras
        col ="orange") #color caja

# Añadir línea con la media
abline(h = mean(prim_Mat_5[!is.na(prim_Mat_5$Promedio),]$Promedio), col = 4, lwd = 2) # Línea completa

# Añadir punto con la media
points(mean(prim_Mat_5[!is.na(prim_Mat_5$Promedio),]$Promedio), col = 3, pch = 19)
# Out:
#   Promedio  frequency acumulado
# 1 (6,6.8]   123       123
# 2 (6.8,7.6] 116       239
# 3 (7.6,8.4] 181       420
# 4 (8.4,9.2] 111       531
# 5 (9.2,10]  121       652
# Plot with title "Boxplot para la asignatura Matemática de 5°grado de Primaria"

# %%
hist(x = prim_Mat_5$Promedio,
     probability = TRUE, 
     col="orange",
     breaks = c(6,6.8,7.6,8.4,9.2,10), #cantidad de barras que quiero
     xaxp = c(6, 10, 5), #acomoda el eje x para ver bien los valores
     ylim = c(0, 0.5),
     xlab="notas",
     ylab="frecuencia absoluta",
     main ="Histograma para la asignatura Matemática de 5°grado de Primaria")
# Out:
# Plot with title "Histograma para la asignatura Matemática de 5°grado de Primaria"

# %%
prim_Mat_6 <- filter(Diamante, Curso== 6 & Materia=="MATEMATICA")

prim_Mat_6[!is.na(prim_Mat_6$Promedio),] %>% 
  mutate(Promedio = cut(Promedio, breaks = 5), na.rm=TRUE) %>% 
  group_by(Promedio) %>% 
  summarise(frequency = n()) %>% 
  mutate(acumulado = cumsum(frequency))

boxplot(prim_Mat_6[!is.na(prim_Mat_6$Promedio),]$Promedio,
        main ="Boxplot para la asignatura Matemática de 6°grado de Primaria",
        horizontal = FALSE,
        sub = "Fuente de elaboración propia",
        whisklty = 2,       # Tipo línea bigotes
        whisklwd = 2,       # Ancho línea bigotes
        whiskcol = "red",   # Color bigotes
        staplelty = 3,      # Tipo línea barras
        staplelwd = 2,      # Ancho línea barras
        staplecol = "blue",  #Color barras
        col ="orange") #color caja

# Añadir línea con la media
abline(h = mean(prim_Mat_6[!is.na(prim_Mat_6$Promedio),]$Promedio), col = 4, lwd = 2) # Línea completa

# Añadir punto con la media
points(mean(prim_Mat_6[!is.na(prim_Mat_6$Promedio),]$Promedio), col = 3, pch = 19)
# Out:
#   Promedio  frequency acumulado
# 1 (6,6.8]   132       132
# 2 (6.8,7.6] 110       242
# 3 (7.6,8.4] 193       435
# 4 (8.4,9.2] 134       569
# 5 (9.2,10]  115       684
# Plot with title "Boxplot para la asignatura Matemática de 6°grado de Primaria"

# %%
hist(x = prim_Mat_6$Promedio,
     probability = TRUE, 
     col="orange",
     breaks = c(6,6.8,7.6,8.4,9.2,10), #cantidad de barras que quiero
     xaxp = c(6, 10, 5), #acomoda el eje x para ver bien los valores
     ylim = c(0, 0.5),
     xlab="notas",
     ylab="frecuencia absoluta",
     main ="Histograma para la asignatura Matemática de 6°grado de Primaria")
# Out:
# Plot with title "Histograma para la asignatura Matemática de 6°grado de Primaria"
